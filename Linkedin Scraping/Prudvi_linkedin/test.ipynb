# %%
import pandas as pd

# %%
df= pd.read_csv('post_links.csv', index_col= False, header=None)

# %%
post_links= df.iloc[1:, 0].tolist()

# %%
post_links
# Out:
# ['urn:li:activity:6534599640774471680',
#  'urn:li:activity:6526828177984184320',
#  'urn:li:activity:6509779969256853504',
#  'urn:li:activity:6509100808192262144',
#  'urn:li:activity:6505874470815789056',
#  'urn:li:activity:6499001135288901632',
#  'urn:li:activity:6484780212960759808',
#  'urn:li:activity:6484162075076726784',
#  'urn:li:activity:6481466397321990144',
#  'urn:li:activity:6480012032132382720',
#  'urn:li:activity:6477888694610124801',
#  'urn:li:activity:6472840173490139136',
#  'urn:li:activity:6469535469557342208',
#  'urn:li:activity:6467861697796325376',
#  'urn:li:activity:6467372881373425665',
#  'urn:li:activity:6466612073966211072',
#  'urn:li:activity:6462520026783158272',
#  'urn:li:activity:6459194925920686080',
#  'urn:li:activity:6455687924288716800',
#  'urn:li:activity:6455574031444824064',
#  'urn:li:activity:6454048517584457728',
#  'urn:li:activity:6454046651244994560',
#  'urn:li:activity:6453473591206998016',
# ...
