# %%
import numpy as np 
import pandas as pd

# %%
df= pd.read_csv("Shares.csv")

# %%
df.columns
# Out:
# Index(['Date', 'ShareLink', 'ShareCommentary', 'SharedURL', 'MediaURL',
#        'Visibility'],
#       dtype='object')

# %%
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import requests
from time import sleep

# %%
df.ShareCommentary.head()
# Out:
# 0    A girl decided to WED a guy who is a entrepren...
# 1    Who sells on Independence Day ? For me, it's t...
# 2    An aggressive journalist to Sushma Swaraj :"\r...
# 3    "\r\n"I have prepared an extensive hands on re...
# 4    You will live on in every machine's buzz, "\r\...
# Name: ShareCommentary, dtype: object

# %%
df.ShareCommentary[0].encode('UTF-8').decode('unicode_escape')
# Out:
# 'A girl decided to WED a guy who is a entrepreneur"\r\n""\r\n"On the day of the date"\r\n""\r\n"Girl : So, what are your hobbies ?"\r\n""\r\n"Guy : Umm.... bathing and eating"\r\n""\r\n"Girl\'s face : #!$%^&@#$"\r\n""\r\n"Guy : That\'s what I do when I get free time ! That\'s the definition of hobby right !!"\r\n""\r\n"#World #Entrepreneurship #day (WED)"\r\n""\r\n"Enough of praising the entrepreneurs. Dedicated to the amazing women behind the entrepreneurs. "\r\n""\r\n"#entrepreneurs '

# %%
from pyPDF2 import PdfFileWriter, PdfFileReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dcfbf25111d7> in <module>()
# ----> 1 from pyPDF2 import PdfFileWriter, PdfFileReader
#
# ModuleNotFoundError: No module named 'pyPDF2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
