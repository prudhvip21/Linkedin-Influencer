# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd
import itertools
import re
from ast import literal_eval

# %%
df= pd.read_csv('../new_data_dump/Shares.csv')

# %%
df.head()
# Out:
#                   Date                                          ShareLink  \
# 0  2020-02-14 05:47:18  https://www.linkedin.com/feed/update/urn%3Ali%...
# 1  2020-02-12 12:20:01  https://www.linkedin.com/feed/update/urn%3Ali%...
# 2  2020-02-12 12:20:01  https://www.linkedin.com/feed/update/urn%3Ali%...
# 3  2020-02-12 12:20:01  https://www.linkedin.com/feed/update/urn%3Ali%...
# 4  2020-02-12 12:20:01  https://www.linkedin.com/feed/update/urn%3Ali%...
#
#                                      ShareCommentary SharedURL MediaURL  \
# 0  On this 'Love'ly day, just reminding everyone ...       NaN      NaN
# 1  These  insights are from feedback form circula...       NaN      NaN
# 2  These  insights are from feedback form circula...       NaN      NaN
# 3  These  insights are from feedback form circula...       NaN      NaN
# 4  These  insights are from feedback form circula...       NaN      NaN
#
#        Visibility
# 0  MEMBER_NETWORK
# 1  MEMBER_NETWORK
# 2  MEMBER_NETWORK
# 3  MEMBER_NETWORK
# 4  MEMBER_NETWORK

# %%
df.shape
# Out:
# (389, 6)

# %%
for link in df.ShareLink:
    print(link)
    print()
# Out:
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6633959669176037376
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6633333726040420352
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6633333726040420352
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6633333726040420352
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6633333726040420352
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6632890985418448896
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6632209820663545856
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6631768988923850752
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6631430365426880512
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6629663094304006144
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6629663094304006144
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6629663094304006144
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6629663094304006144
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6628281894792462337
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6627781517475143680
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6627091296936919040
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6626325046958882816
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6625967837854949377
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6624895143742922752
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6622698390742495233
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6622379585969455104
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6621979176595480576
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6620209523837767680
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6618367137394323456
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6617279293263306753
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6616991111732924417
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6616192811710672896
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6615843958780198912
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6615192780643889152
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6614864274961600512
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6614734394768883712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6614734394768883712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6614725811373207552
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6614360691098914816
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6613993676144250880
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6612930701635481600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6612360072167292928
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6611874074706702336
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6611115007361019904
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6610878654845153280
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6610760873684365312
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6610363486365159424
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6610105465567309824
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6609816254666641408
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6608607256906911744
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6608228351691841536
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6607881388144320513
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6607881388144320513
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6607881388144320513
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6607881388144320513
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6607488724982956032
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6607114990078005248
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6606415233491791872
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6605672482622005248
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6605324282526515200
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6604959655758262272
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6604602733649592320
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6603166280818192384
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6601004999038337024
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6600260530223575040
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6599136458659983360
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6598439124976406528
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6598062029070794752
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6597704517926649856
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6597480477551099904
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596993963117383680
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596720679050149888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6596597094935556096
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6596234376151961600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6595190131878125568
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6594961412106358784
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6594820606754160640
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6594462009557913600
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6594051689358155776
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6593359482716291073
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6593062154381955072
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6591920569015463936
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6591251143668666368
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6590934827132915712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6590821729797541888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6590519678861438976
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6590174171664347136
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6589768119013728256
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6589736185210470400
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6589717369554337792
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6589371902001799168
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6589141199045652480
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6588303494627852288
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6587920944424148992
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6586146280035192833
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6586146280035192833
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6586146280035192833
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6586146280035192833
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6585381500324282368
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6585015549833641984
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6584278394278592512
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6583947167130587137
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6582497773621477376
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6582110231294251008
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6581769011267244032
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6581769011267244032
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6581769011267244032
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6581769011267244032
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6581071244295274496
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6579387469928722432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6579387469928722432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6579387469928722432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6579387469928722432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6579271261946515456
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6578982215370268672
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6577068987966939136
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6576684941524992000
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575630647212249088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6575219403711963136
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6574882547510140928
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6574171373944569856
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6573392161549705216
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6572320568543141888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6570900852800884736
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6570536517666734080
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6569974616670994432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6567639553425928192
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6564724214979457024
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6564027611931078656
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6563760062492442624
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6561822881423118336
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6560762054196715520
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6560472596205404160
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6559306564489052160
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6558601894057603072
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6557125058970644480
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6556781134624194560
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6556363817675264000
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6555386001202741248
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6555299127503220736
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6554222530041876480
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6553842331328573440
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6553842331328573440
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6553842331328573440
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6553842331328573440
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6553466504883605504
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6552411042381697024
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6551325206839943168
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6549872035160522752
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6549168346590433280
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6548802243649388544
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6547834462233821184
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6547341269402775553
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6546951311047389184
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6546611976464855041
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6546017160467144704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6545106052835303424
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6544087399163625472
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6543694194316275712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6543377125582434304
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6543054593595670528
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6542925058057306112
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6542603152754077696
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6542247503272701952
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6541174050352402432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6540771882424205312
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6539707983746695168
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6539066562970771457
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6538659158697312257
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6537555366794891264
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6537214972827664384
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6536927863000657920
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6534099446345629696
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6533636855118815232
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AgroupPost%3A10446044-6533261406140231680
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6532104306399772672
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AgroupPost%3A10446044-6532093482834726912
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AgroupPost%3A10446044-6531760989942181888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6531722404333490177
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6531416861303762944
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6531055671079694336
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6530316521942675456
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6529914456175149056
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6529557203651788800
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6527037964579639296
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AgroupPost%3A10446044-6527030566108401664
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6526787121175461888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6526787121175461888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6526787121175461888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6526787121175461888
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6526024326788026368
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6524515731323789313
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6524090932671938560
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6523863760841609216
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6523764072603807744
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6523387365103370240
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6522275133405655040
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6522004995519410176
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6521740965705805824
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6521290707548897280
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6520934915700289536
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6520934915700289536
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6520934915700289536
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6520934915700289536
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6520492315428118529
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6520232860136366080
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6519916921851342848
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6519086508564148224
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6518694059790430208
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6518471411743453184
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6518328108498677760
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6517708619738386432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6516860393770577920
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6516682333750427648
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6515779765528563712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6514737761075990528
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6514459276721917952
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6513961958868381696
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6513620564417056768
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6513250844530565120
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6511782604109381632
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6511087246131716096
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6510683640203186176
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6510109094538502144
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6509947755958493184
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6509693432368324608
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6509611168640929792
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6509245058477322240
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6508964732945428480
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6508575612813307904
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6508179933595037696
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6506712311045152768
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6506371134215294976
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6506204859556040704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6501744444688072704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6498793587151560704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6496943601300406272
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6496576631468068864
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6496011248210153472
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6495219028146118656
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6494045089785049088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6489738555823308800
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6489721660210507776
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6486833083566915584
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6485732840226025472
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6485082362442027008
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6483535482637651968
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6483535482637651968
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6483535482637651968
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6482809969535225856
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6482431539308261376
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6481718704794107904
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6481330771926839296
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6481330771926839296
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6481330771926839296
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6481330771926839296
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6480664849188782080
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6479986594601373696
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6479535766157529088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6479337320758771712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6479225643929296896
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6479163771704184832
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6478980524068175872
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6478970819082051584
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6478812625173078016
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6478440826098802688
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6477715011555950592
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6476685414630551552
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6476328699208757248
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6476097744116248576
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6475620183309422592
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AgroupPost%3A8720844-6475329695754833920
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6475261525866184704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6474646768402427904
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6474489029395083264
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6470589723621593088
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6470248733031358464
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6469912273405210624
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6467735786480590848
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6466527911582236672
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6443829769296498688
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6443149555180630016
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6441200200882192384
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6440395110881550336
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6438297046293245952
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6438000052702154752
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6434376549381832704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6429704321985839104
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6428941732758544384
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6427463991823560704
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6425986414453841920
#
# https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A6412135473485053952
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6405650869639049216
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6401986304795602944
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6395786872634867712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6394517101943590912
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6388918253053411328
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6387118119730679808
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6386224162918232064
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6384011986673459200
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6383955959307431936
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6382658394045681664
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6382658394045681664
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6382658394045681664
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6382658394045681664
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6370993197342134272
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6366240201525825536
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6363920676419665920
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6362359536627605504
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6361981991038091264
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6359777952762294272
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6358534631578537985
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6357253878039306240
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6356483629467697152
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6355227377085313024
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6354878612382027776
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6354651658865213440
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6354619949805338624
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6353491832026034176
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6352364741394042880
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6347059202694930432
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6346559293701095424
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6346190055157137408
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6346011196289843200
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6345280934111219712
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6343991473209466880
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6339350495290802176
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6331532959300050944
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6328930925866520576
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6328064126367166464
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6323866412314128384
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6318346347900698624
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6318345768482766848
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6318344575408791552
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6313287817204162560
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6312941727569272832
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6312233225666289664
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6311773256156307456
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6308648767583293440
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6307504630398062592
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6303465343360819200
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6292287039274618880
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6278485190679597057
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6278099972277788672
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6263576094021115904
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6261388157363818496
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6255274720590163968
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6228456043752587264
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6220535844751667200
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6220535499002613760
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6214461638976860160
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6210457835449487360
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6210457476035383296
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6207787516817444864
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6199912401807216640
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6198754539340955648
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6195149533257785344
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6195149398545133568
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6172963086882955264
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6171313270448848896
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A6049158394718285824
#
# https://www.linkedin.com/feed/update/urn%3Ali%3Ashare%3A5914309501749583872

# %%
i=0
while(i < df.shape[0]):
            if pd.isnull(df.Link[i]):
                df.Message[i-1]= str(df.Message[i-1]) + str(df.Date[i])
                df.Message[i-1]= df.Message[i-1].replace('nan', '')
                df.drop(df.index[i], inplace= True)
                df.reset_index(drop= True, inplace= True)
                i = i - 1
            i = i + 1

# %%
new_df= pd.read_csv('../new_data_dump/Comments.csv')

# %%
i=0
while(i < new_df.shape[0]):
            if pd.isnull(new_df.Link[i]):
                new_df.Message[i-1]= str(new_df.Message[i-1]) + str(new_df.Date[i])
                new_df.Message[i-1]= new_df.Message[i-1].replace('nan', '')
                new_df.drop(new_df.index[i], inplace= True)
                new_df.reset_index(drop= True, inplace= True)
                i = i - 1
            i = i + 1

# %%
new_comments_df = new_df[~new_df.Link.isin(df.Link)]

# %%
new_comments_df.to_csv('Comments_new.csv', index= False)

# %%
new_comments_df.Link
# Out:
# 0      https://www.linkedin.com/feed/update/urn%3Ali%...
# 1      https://www.linkedin.com/feed/update/urn%3Ali%...
# 2      https://www.linkedin.com/feed/update/urn%3Ali%...
# 3      https://www.linkedin.com/feed/update/urn%3Ali%...
# 4      https://www.linkedin.com/feed/update/urn%3Ali%...
#                              ...
# 309    https://www.linkedin.com/feed/update/urn%3Ali%...
# 310    https://www.linkedin.com/feed/update/urn%3Ali%...
# 311    https://www.linkedin.com/feed/update/urn%3Ali%...
# 312    https://www.linkedin.com/feed/update/urn%3Ali%...
# 314    https://www.linkedin.com/feed/update/urn%3Ali%...
# Name: Link, Length: 312, dtype: object

# %%
new_df= pd.read_csv()

# %%
pd.set_option('display.max_rows', 300)

# %%
df= pd.read_csv('Data_New/comments_likes_data_7.csv', encoding='utf-8')

# %%
df.columns
# Out:
# Index(['comment_post_link', 'comment_content', 'comment_likes_counts',
#        'like_names', 'like_headlines', 'like_profile_links',
#        'comment_reply_counts', 'comments_replies_content',
#        'comments_replies_names', 'comments_replies_headlines',
#        'comments_replies_links'],
#       dtype='object')

# %%
df
# Out:
#                                     comment_post_link  \
# 0   https://www.linkedin.com/feed/update/urn%3Ali%...
# 1   https://www.linkedin.com/feed/update/urn%3Ali%...
# 2   https://www.linkedin.com/feed/update/urn%3Ali%...
# 3   https://www.linkedin.com/feed/update/urn%3Ali%...
# 4   https://www.linkedin.com/feed/update/urn%3Ali%...
# 5   https://www.linkedin.com/feed/update/urn%3Ali%...
# 6   https://www.linkedin.com/feed/update/urn%3Ali%...
# 7   https://www.linkedin.com/feed/update/urn%3Ali%...
# 8   https://www.linkedin.com/feed/update/urn%3Ali%...
# 9   https://www.linkedin.com/feed/update/urn%3Ali%...
# 10  https://www.linkedin.com/feed/update/urn%3Ali%...
# 11  https://www.linkedin.com/feed/update/urn%3Ali%...
# 12  https://www.linkedin.com/feed/update/urn%3Ali%...
# 13  https://www.linkedin.com/feed/update/urn%3Ali%...
# 14  https://www.linkedin.com/feed/update/urn%3Ali%...
# 15  https://www.linkedin.com/feed/update/urn%3Ali%...
# 16  https://www.linkedin.com/feed/update/urn%3Ali%...
# 17  https://www.linkedin.com/feed/update/urn%3Ali%...
# 18  https://www.linkedin.com/feed/update/urn%3Ali%...
# 19  https://www.linkedin.com/feed/update/urn%3Ali%...
#
#                                       comment_content  comment_likes_counts  \
# 0   The sadder thing is the most reliable informat...                    19
# 1   I really like your posts on edutech sir ! Woul...                     3
# 2                                  Good to see. !\n\n                     3
# 3   And you have to be a bayesian to be naive !! T...                    18
# 4   Before you ask, give !! Summary of your post !...                    11
# 5   95% of 50 is almost as good 5% of 1000 FOCUS o...                    22
# 6   Lakshmi Padmanaban ha ha. Have seen both and a...                     2
# 7                     Omg.. pls. Not even 0.0001%\n\n                     0
# 8                       srinivasan saripalli yes.\n\n                     0
# 9        Srivatsan Srinivasan Thanks. Means a lot\n\n                     0
# 10  Ha ha. I am taking this as a compliment. Yes, ...                     1
# 11  3.41 has a good view of road which shows a big...                     2
# 12                       Thanks a lot Manvi Madan\n\n                     1
# 13                                    Sent you PM\n\n                     0
# 14                             Thanks. Very true.\n\n                     1
# 15                                   Very true !!\n\n                     0
# 16  https://www.thehindu.com/sci-tech/technology/o...                     2
# 17                                             🤣🤣\n\n                     0
# 18  Very true.. !! Been struggling to keep focusse...                     1
# 19  When Sachin Tripathi asked me to define whats ...                    25
#
#                                            like_names  \
# 0   ['\n          Shambhavi Aggarwal\n            ...
# 1   ['\n          Nalini Singh\n            \n    ...
# 2   ['\n          Saish Urumkar\n            \n   ...
# 3   ['\n          Sandhaya Kumari\n            \n ...
# 4   ['\n          Srivatsan Srinivasan\n          ...
# 5   ['\n          Mehul Purohit\n            \n   ...
# 6   ['\n          Lakshmi Padmanaban\n            ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  ['\n          Vanshika Agrawal\n            \n...
# 11  ['\n          Bharath Gujjula\n            \n ...
# 12  ['\n          Manvi Madan\n            \n    2...
# 13                                                NaN
# 14  ['\n          Avi Garg\n            \n    2nd ...
# 15                                                NaN
# 16  ['\n          Dilpreet Singh\n            \n  ...
# 17                                                NaN
# 18  ['\n          Reddeiah Pidugu\n            \n ...
# 19  ['\n          Amanjeet Sahu\n            \n   ...
#
#                                        like_headlines  \
# 0   ['Machine learning enthusiast', 'Data Scientis...
# 1   ['Big Data Enthusiast • ETL Developer • Consul...
# 2   ['5G NR | BSC-RNC | Cloud | IOT | ML | Securit...
# 3   ['Intern at Deep Cognition', 'Business Strateg...
# 4   ['Chief Data Scientist | Data (Big, Huge, Smal...
# 5   ['Software Developer(AI) at Office Beacon LLC'...
# 6   ['Freelance Copywriter | Content Writer | Copy...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                  ['Project Manager at upGrad.com']
# 11  ['A Machine Learning (ML) and Deep Leaning (DL...
# 12  ['Business Intelligence & Insights Analyst at ...
# 13                                                NaN
# 14          ['Senior Big Data Engineer|NIT Hamirpur']
# 15                                                NaN
# 16  ['Co-founder Aqua18', 'Data Scientist at IKS H...
# 17                                                NaN
# 18              ['Data Engineer (Python/Java/Scala)']
# 19  ['Data Science Intern at SupervisedLearning.co...
#
#                                    like_profile_links  comment_reply_counts  \
# 0   ['https://www.linkedin.com/in/shambhavi-aggarw...                     2
# 1   ['https://www.linkedin.com/in/nalini-singh-8ba...                     0
# 2   ['https://www.linkedin.com/in/saish-mlnetwengg...                     0
# 3   ['https://www.linkedin.com/in/sandhaya4u/', 'h...                     1
# 4   ['https://www.linkedin.com/in/srivatsan-sriniv...                     0
# 5   ['https://www.linkedin.com/in/mehul-purohit-1b...                     3
# 6   ['https://www.linkedin.com/in/lakshmipadmanaba...                     0
# 7                                                 NaN                     0
# 8                                                 NaN                     0
# 9                                                 NaN                     0
# 10  ['https://www.linkedin.com/in/vanshika-agrawal...                     0
# 11  ['https://www.linkedin.com/in/bharath-gujjula/...                     0
# 12        ['https://www.linkedin.com/in/manvimadan/']                     0
# 13                                                NaN                     0
# 14  ['https://www.linkedin.com/in/avi-garg-a2754b6...                     0
# 15                                                NaN                     0
# 16  ['https://www.linkedin.com/in/dilpreet-singh-c...                     0
# 17                                                NaN                     0
# 18       ['https://www.linkedin.com/in/reddypidugu/']                     0
# 19  ['https://www.linkedin.com/in/amanjeetsahu/', ...                     2
#
#                              comments_replies_content  \
# 0   ['\n\nPrudhvi Potuganti you are right as they ...
# 1                                              ['NA']
# 2                                              ['NA']
# 3   ['\n\n🙂🙂..The frequentists who think they know...
# 4                                              ['NA']
# 5   ["\n\nThat's a great way to put it and a persp...
# 6                                              ['NA']
# 7                                              ['NA']
# 8                                              ['NA']
# 9                                              ['NA']
# 10                                             ['NA']
# 11                                             ['NA']
# 12                                             ['NA']
# 13                                             ['NA']
# 14                                             ['NA']
# 15                                             ['NA']
# 16                                             ['NA']
# 17                                             ['NA']
# 18                                             ['NA']
# 19    ['\n\nYeah Prudhvi\n\n', '\n\nAgree Ankit\n\n']
#
#                                comments_replies_names  \
# 0                 ['Abhirup Goswami', 'Nikhil Kumar']
# 1                                              ['NA']
# 2                                              ['NA']
# 3                                  ['Ritesh Bhagwat']
# 4                                              ['NA']
# 5   ['Lakshmi Padmanaban', 'Prudhvi Potuganti', 'L...
# 6                                              ['NA']
# 7                                              ['NA']
# 8                                              ['NA']
# 9                                              ['NA']
# 10                                             ['NA']
# 11                                             ['NA']
# 12                                             ['NA']
# 13                                             ['NA']
# 14                                             ['NA']
# 15                                             ['NA']
# 16                                             ['NA']
# 17                                             ['NA']
# 18                                             ['NA']
# 19                    ['Ankit Rathi', 'Rishi Narang']
#
#                            comments_replies_headlines  \
# 0   ['\n        Student at IIT BHU Varanasi\n     ...
# 1                                              ['NA']
# 2                                              ['NA']
# 3   ['\n        Data Scientist | Applied Mathemati...
# 4                                              ['NA']
# 5   ['\n        Freelance Copywriter | Content Wri...
# 6                                              ['NA']
# 7                                              ['NA']
# 8                                              ['NA']
# 9                                              ['NA']
# 10                                             ['NA']
# 11                                             ['NA']
# 12                                             ['NA']
# 13                                             ['NA']
# 14                                             ['NA']
# 15                                             ['NA']
# 16                                             ['NA']
# 17                                             ['NA']
# 18                                             ['NA']
# 19  ['\n        Lead Architect - Data & AI | Autho...
#
#                                comments_replies_links
# 0   ['https://www.linkedin.com/in/abhirup-goswami-...
# 1                                              ['NA']
# 2                                              ['NA']
# 3          ['https://www.linkedin.com/in/riteshb15/']
# 4                                              ['NA']
# 5   ['https://www.linkedin.com/in/lakshmipadmanaba...
# 6                                              ['NA']
# 7                                              ['NA']
# 8                                              ['NA']
# 9                                              ['NA']
# 10                                             ['NA']
# 11                                             ['NA']
# 12                                             ['NA']
# 13                                             ['NA']
# 14                                             ['NA']
# 15                                             ['NA']
# 16                                             ['NA']
# 17                                             ['NA']
# 18                                             ['NA']
# 19  ['https://www.linkedin.com/in/ankitrathi/', 'h...

# %%
def return_likes(df):
    df.like_names= df.like_names.fillna("['NaN']")
    df.like_headlines= df.like_headlines.fillna("['NaN']")
    df.like_profile_links= df.like_profile_links.fillna("['NaN']")
    df['like_names']= df['like_names'].apply(literal_eval)
    df['like_headlines']= df['like_headlines'].apply(literal_eval)
    df['like_profile_links']= df['like_profile_links'].apply(literal_eval)
    raw_names= list(itertools.chain.from_iterable(df.like_names.tolist()))
    names= list()
    for name in raw_names:
        try:
            names.append(re.match('^.*(?=(\n|•))', name).group(0))
        except Exception:
            names.append(name)
    headlines= list(itertools.chain.from_iterable(df.like_headlines.tolist()))
    links= list(itertools.chain.from_iterable(df.like_profile_links.tolist()))
    likes_df= pd.DataFrame({'name': names, 'headlines': headlines, 'links': links})
    likes_df= likes_df[likes_df.name != 'NaN']
    return likes_df

# %%
df.columns
# Out:
# Index(['comment_post_link', 'comment_content', 'comment_likes_counts',
#        'like_names', 'like_headlines', 'like_profile_links',
#        'comment_reply_counts', 'comments_replies_content',
#        'comments_replies_names', 'comments_replies_headlines',
#        'comments_replies_links'],
#       dtype='object')

# %%
df.comments_replies_names= df.comments_replies_names.apply(literal_eval)

# %%
df.comments_replies_names

# %%
def replies_df(df):
    df.comments_replies_content= df.comments_replies_content.fillna("['NaN']")
    df.comments_replies_names= df.comments_replies_names.fillna("['NaN']")
    df.comments_replies_headlines= df.comments_replies_headlines.fillna("['NaN']")
    df.comments_replies_links= df.comments_replies_links.fillna("['NaN']")
    df['comments_replies_content']= df['comments_replies_content'].apply(literal_eval)
    df['comments_replies_names']= df['comments_replies_names'].apply(literal_eval)
    df['comments_replies_headlines']= df['comments_replies_headlines'].apply(literal_eval)
    df['comments_replies_links']= df['comments_replies_links'].apply(literal_eval)
    raw_names= list(itertools.chain.from_iterable(df.comments_replies_names.tolist()))
    names= list()
    for name in raw_names:
        try:
            names.append(re.match('^.*(?=(\n|•))', name).group(0))
        except Exception:
            names.append(name)
    headlines= list(itertools.chain.from_iterable(df.comments_replies_headlines.tolist()))
    links= list(itertools.chain.from_iterable(df.like_profile_links.tolist()))
    likes_df= pd.DataFrame({'name': names, 'headlines': headlines, 'links': links})
    likes_df= likes_df[likes_df.name != 'NaN']
    return likes_df

# %%
likes_df= return_likes(df)

# %%
replies_df= replies_df(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-efd24d5abe30> in <module>
# ----> 1 replies_df= replies_df(df)
#
# <ipython-input-47-2cb5df90b2ac> in replies_df(df)
#       3     df.like_headlines= df.like_headlines.fillna("['NaN']")
#       4     df.like_profile_links= df.like_profile_links.fillna("['NaN']")
# ----> 5     df['like_names']= df['like_names'].apply(literal_eval)
#       6     df['like_headlines']= df['like_headlines'].apply(literal_eval)
#       7     df['like_profile_links']= df['like_profile_links'].apply(literal_eval)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/lib/python3.7/ast.py in literal_eval(node_or_string)
#      89                     return left - right
#      90         return _convert_signed_num(node)
# ---> 91     return _convert(node_or_string)
#      92
#      93
#
# ~/anaconda3/lib/python3.7/ast.py in _convert(node)
#      88                 else:
#      89                     return left - right
# ---> 90         return _convert_signed_num(node)
#      91     return _convert(node_or_string)
#      92
#
# ~/anaconda3/lib/python3.7/ast.py in _convert_signed_num(node)
#      61             else:
#      62                 return - operand
# ---> 63         return _convert_num(node)
#      64     def _convert(node):
#      65         if isinstance(node, Constant):
#
# ~/anaconda3/lib/python3.7/ast.py in _convert_num(node)
#      53         elif isinstance(node, Num):
#      54             return node.n
# ---> 55         raise ValueError('malformed node or string: ' + repr(node))
#      56     def _convert_signed_num(node):
#      57         if isinstance(node, UnaryOp) and isinstance(node.op, (UAdd, USub)):
#
# ValueError: malformed node or string: ['Preksha Kaparwan • Following']

# %%
likes_df.name.value_counts()
# Out:
# Abhirup Goswami                          2
# Preksha Kaparwan                         2
# Haripriya Salapaka                       2
# Krishnan Santhosh Kumar                  2
# Swapnil Chavan                           2
# saigayatri vadali                        1
# Arpan Shrivastava                        1
# Apurwa Raikwar                           1
# Yeshavanth Nanjundappa                   1
# Dalee Davis                              1
# Olawale Ibrahim                          1
# Sidharth SK                              1
# Ankit Rathi                              1
# karthikeyan MG                           1
# Rahul Jain                               1
# Dayanithi Selvaraji                      1
# Nagesh Kalluri                           1
# Shubham Tripathi                         1
# Kuldeep Singh                            1
# Mehul Harsora                            1
# Santosh Yadav, PhD (EE), IIT Guwahati    1
# Saurabh Goel,AINS                        1
# Deepak Chaudhary                         1
# Ramraj Sekar                             1
# Srivatsan Srinivasan                     1
# Ambika Iragappa                          1
# Chandan Yadav                            1
# Apoorva CR                               1
# Rishabh Jain                             1
# Sreekumar Radhakrishnapillai, Ph.D       1
# Gautam .                                 1
# sairam uppugundla                        1
# Aryabhatta (.                            1
# Prudhvi Potuganti                        1
# Jatin Dinesh                             1
# Nagesh GP                                1
# Sourav Maharana                          1
# Bhavesh Wadhwani                         1
# ASHOK KUMAR CHITTURI                     1
# Sunkoju Suryateja                        1
# Ritesh Bhagwat                           1
# Roshan T John ( Data Scientist )         1
# Mousam Singh                             1
# Suresh Pathange                          1
# Deep Chatterjee                          1
# Sailesh Satpathy                         1
# Shivendra Agarwal                        1
# Shibu Nair                               1
# Amrita Angappa                           1
# Chakravarthi Palvadi                     1
# Dr Aniruddha Malpani                     1
# Mayank Gupta                             1
# Sandeep Dubey                            1
# Taj Tabir Azad Khan                      1
# Deeparaj Annamalai                       1
# Sridhar Joga                             1
# Aritra Das                               1
# Swetha Kondapalli                        1
# Ankush Rana                              1
# Name: name, dtype: int64

# %%
import pandas as pd
dump_df= pd.read_csv("../data_dump/Comments.csv")

# %%
dump_df.columns
# Out:
# Index(['Date', 'Link', 'Message'], dtype='object')

# %%
dump_df.Link.isna().sum()
# Out:
# 117

# %%
pd.set_option('display.max_rows', 800)

# %%
i=0
while(i < dump_df.shape[0]):
    if pd.isnull(dump_df.Link[i]):
        dump_df.Message[i-1]= str(dump_df.Message[i-1]) + str(dump_df.Date[i])
        dump_df.Message[i-1]= dump_df.Message[i-1].replace('nan', '')
        dump_df.drop(dump_df.index[i], inplace= True)
        dump_df.reset_index(drop= True, inplace= True)
        i= i-1
    i = i + 1

# %%
dump_df.Message[0]
# Out:
# 'Actually, I wanted a girl/women entrepreneur to write the first line. So that I could ask them the opposite version - like what would be hobby answer from a woman entrepreneur. \r\n\r\nNow I should edit my post to tag women entrepreneurs whom I adore to write an opposite version !!. Bdw, I have a ton of women entrepreneurs in my network and I deeply value their work. FYI, one of my non profit - The Positive India has a woman Co Founder. \r\n\r\nPreksha Kaparwan Any help in opposite version ??\r\n\r\nOthers who are replying, request not to extrapolate too far'

# %%
len(dump_df.Link.unique())
# Out:
# 457
